# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import Image


from tyssue import config, Sheet, SheetGeometry, History, EventManager
from tyssue.draw import sheet_view
from tyssue.generation import three_faces_sheet
from tyssue.draw.plt_draw import plot_forces

from tyssue.dynamics import PlanarModel

from tyssue.solvers.viscous import EulerSolver
from tyssue.draw.plt_draw import create_gif


geom  = SheetGeometry
model = PlanarModel

sheet = Sheet.planar_sheet_3d('planar', nx=6, ny=6, 
                             distx=1, disty=1)
sheet.sanitize(trim_borders=True, order_edges=True)
geom.update_all(sheet)
fig, ax = sheet_view(sheet)

# %% [markdown]
# # The  `history` object

# %% [markdown]
# The `History` class defines the object in charge of storing the evolving epithelium during the course of the simulation. It allows to access to different time points of a simulation from one unique epithelium.
#
# Most of the time, we use `HistoryHDF5` class, that writes each time step to a file, which can be useful for big files. It is also possible to read an hf5 file to analyze a simulation later.
#
#
# In the solver, we use the `history.record` method to store the epithelium.In the `create_gif` function, we use the `history.retrieve` method to get back the epithelium at a given time point. Please see the API for more details.

# %%
history = History(sheet, save_every=2, dt=1)

for i in range(10):
    
    geom.scale(sheet, 1.02, list('xy'))
    geom.update_all(sheet)
    # record only every `save_every` time 
    history.record()

create_gif(history, 'simple_growth.gif', num_frames=len(history))


Image('simple_growth.gif')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\Thomas\anaconda3\envs\cellbio\lib\site-packages\IPython\core\display.py:1045, in Image._data_and_metadata(self, always_both)
#    1044 try:
# -> 1045     b64_data = b2a_base64(self.data, newline=False).decode("ascii")
#    1046 except TypeError as e:
#
# TypeError: a bytes-like object is required, not 'str'
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\Thomas\anaconda3\envs\cellbio\lib\site-packages\IPython\core\formatters.py:974, in MimeBundleFormatter.__call__(self, obj, include, exclude)
#     971     method = get_real_method(obj, self.print_method)
#     973     if method is not None:
# --> 974         return method(include=include, exclude=exclude)
#     975     return None
#     976 else:
#
# File c:\Users\Thomas\anaconda3\envs\cellbio\lib\site-packages\IPython\core\display.py:1035, in Image._repr_mimebundle_(self, include, exclude)
#    1033 if self.embed:
#    1034     mimetype = self._mimetype
# -> 1035     data, metadata = self._data_and_metadata(always_both=True)
#    1036     if metadata:
#    1037         metadata = {mimetype: metadata}
#
# File c:\Users\Thomas\anaconda3\envs\cellbio\lib\site-packages\IPython\core\display.py:1047, in Image._data_and_metadata(self, always_both)
#    1045     b64_data = b2a_base64(self.data, newline=False).decode("ascii")
#    1046 except TypeError as e:
# -> 1047     raise FileNotFoundError(
#    1048         "No such file or directory: '%s'" % (self.data)) from e
#    1049 md = {}
#    1050 if self.metadata:
#
# FileNotFoundError: No such file or directory: 'simple_growth.gif'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\Thomas\anaconda3\envs\cellbio\lib\site-packages\IPython\core\display.py:1045, in Image._data_and_metadata(self, always_both)
#    1044 try:
# -> 1045     b64_data = b2a_base64(self.data, newline=False).decode("ascii")
#    1046 except TypeError as e:
#
# TypeError: a bytes-like object is required, not 'str'
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\Thomas\anaconda3\envs\cellbio\lib\site-packages\IPython\core\formatters.py:344, in BaseFormatter.__call__(self, obj)
#     342     method = get_real_method(obj, self.print_method)
#     343     if method is not None:
# --> 344         return method()
#     345     return None
#     346 else:
#
# File c:\Users\Thomas\anaconda3\envs\cellbio\lib\site-packages\IPython\core\display.py:1067, in Image._repr_png_(self)
#    1065 def _repr_png_(self):
#    1066     if self.embed and self.format == self._FMT_PNG:
# -> 1067         return self._data_and_metadata()
#
# File c:\Users\Thomas\anaconda3\envs\cellbio\lib\site-packages\IPython\core\display.py:1047, in Image._data_and_metadata(self, always_both)
#    1045     b64_data = b2a_base64(self.data, newline=False).decode("ascii")
#    1046 except TypeError as e:
# -> 1047     raise FileNotFoundError(
#    1048         "No such file or directory: '%s'" % (self.data)) from e
#    1049 md = {}
#    1050 if self.metadata:
#
# FileNotFoundError: No such file or directory: 'simple_growth.gif'

# %% [markdown]
# `retrieve` returns an epithelium of the same type as the original:

# %%
type(history.retrieve(5))
# Out:
# tyssue.core.sheet.Sheet

# %% [markdown]
# Iterating over an `history` object yields a time and a `sheet` object:

# %%
for t, sheet in history:
    print(f"mean area at {t}: {sheet.face_df.area.mean():.3f}", )
# Out:
# mean area at 0.0: 0.781
# mean area at 1.0: 0.813
# mean area at 3.0: 0.880
# mean area at 5.0: 0.952
# mean area at 7.0: 1.031
# mean area at 9.0: 1.116

# %% [markdown]
# The `vert_h`, `edge_h` and `face_h` DataFrames hold the history:

# %%
history.vert_h.head()
# Out:
#    vert  basal_shift      y  z    x  rho  is_active  height  time
# 0     0          4.0  2.625  0  0.5    0          1    -4.0   0.0
# 1     1          4.0  3.375  0  1.5    0          1    -4.0   0.0
# 2     2          4.0  2.625  0  2.5    0          1    -4.0   0.0
# 3     3          4.0  3.375  0  0.5    0          1    -4.0   0.0
# 4     4          4.0  3.625  0  1.0    0          1    -4.0   0.0

# %% [markdown]
# You can plot the evolution of a column vs time:

# %%
fig, ax = plt.subplots()

ax.scatter(history.face_h['time'], history.face_h['area'], alpha=0.2, s=12)

history.face_h.groupby('time').area.mean().plot(ax=ax)
# Out:
# <Axes: xlabel='time'>

# %% [markdown]
# # Quasistatic solver
#
# A common way to describe an epithelium is with the **quasistatic approximation**: we assume that at any point in time, without exterior perturbation, the epithelium is at an **energy minimum**. For a given expression of the model's Hamiltonian, we thus search the position of the vertices corresponding to the minimum of energy.
#
# ### The Farhadifar model
#
# A very common formulation for the epithelium mechanical energy was given in [Farhadifar et al. in 2007](https://doi.org/10.1016/j.cub.2007.11.049).
#
# The energy is the sum of an area elasticity, a contractility and a line tension:
# $$
# E = \sum_\alpha \frac{K_A}{2}(A_\alpha - A_0)^2 + \sum_\alpha \Gamma P_\alpha^2 + \sum_{ij} \Lambda \ell_{ij}
# $$
#
#
#
#
# This model has been predifined in tyssue as the default `PlanarModel`. We can use it in combination with a `Solver` object to find the energy minimum of our sheet.
#
# To add the various columns in the dataframes (as we did above) we use a  **specification dictionnary** with the required parameters.

# %%
#from tyssue.config.dynamics import quasistatic_plane_spec
from tyssue.dynamics.planar_vertex_model import PlanarModel as smodel
from tyssue.solvers import QSSolver
from pprint import pprint

specs = {
    'edge': {
        'is_active': 1,
        'line_tension': 0.12,
        'ux': 0.0,
        'uy': 0.0,
        'uz': 0.0
    },
   'face': {
       'area_elasticity': 1.0,
       'contractility': 0.04,
       'is_alive': 1,
       'prefered_area': 1.0},
   'settings': {
       'grad_norm_factor': 1.0,
       'nrj_norm_factor': 1.0
   },
   'vert': {
       'is_active': 1
   }
}


# Update the specs (adds / changes the values in the dataframes' columns)
sheet.update_specs(specs)

pprint(specs)
# Out:
# {'edge': {'is_active': 1,
#           'line_tension': 0.12,
#           'ux': 0.0,
#           'uy': 0.0,
#           'uz': 0.0},
#  'face': {'area_elasticity': 1.0,
#           'contractility': 0.04,
#           'is_alive': 1,
#           'prefered_area': 1.0},
#  'settings': {'grad_norm_factor': 1.0, 'nrj_norm_factor': 1.0},
#  'vert': {'is_active': 1}}

# %%
E_t = smodel.compute_energy(sheet)
print("Total energy: ", E_t)
# Out:
# Total energy:  13.44300213965199

# %%
smodel.compute_gradient(sheet).head()
# Out:
#                 gx        gy   gz
# srce
# 0    -4.934718e-01 -0.039296  0.0
# 1     0.000000e+00  0.163215  0.0
# 2    -9.020562e-16 -0.051386  0.0
# 3    -3.863108e-01  0.021599  0.0
# 4    -6.386835e-01  0.387129  0.0

# %% [markdown]
# The energy minimum is found with a _gradient descent_ strategy, the vertices are displaced in the direction opposite to the spatial derivative of the energy. Actually, this defines the **force** on the vertices.
#
# The gradient descent algorithm is provided by scipy [`minimize`](https://docs.scipy.org/doc/scipy/reference/optimize.minimize-lbfgsb.html#optimize-minimize-lbfgsb) function, with the L-BFGSB method by default.

# %%
# Find energy minimum
solver = QSSolver()
res = solver.find_energy_min(sheet, geom, smodel)

print("Successfull gradient descent? ", res['success'])
fig, ax = sheet_view(sheet)

fig.set_size_inches(10, 10)
ax.set_aspect('equal')
# Out:
# Successfull gradient descent?  True

# %% [markdown]
# Keyword arguments to `find_energy_min` method are passed to scipy's `minimize`, so it is possible for example to reduce the termination criteria:

# %%
sheet.face_df.loc[4, "prefered_area"] = 2.0

res = solver.find_energy_min(sheet, geom, smodel, options={"ftol": 1e-2})

# %% [markdown]
# The method returns the output of the minimize function.

# %%
print("Boolean for the convergence success: ")
print(res.success)

print("Number of function evaluations: ")

print(res.nfev) 

print("Information on the convergence: ")
print(res.message)
# Out:
# Boolean for the convergence success:
# True
# Number of function evaluations:
# 9
# Information on the convergence:
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH

# %% [markdown]
# The  solver object also provides facilities to approximate the gradient (can be useful when debugging new effectors) and evaluate the error between the actual gradient and the approximate one.

# %%
print('Total gradient error: ')
solver.check_grad(sheet, geom, model)
# Out:
# Total gradient error:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[33], line 2
#       1 print('Total gradient error: ')
# ----> 2 solver.check_grad(sheet, geom, model)
#
# File c:\Users\Thomas\anaconda3\envs\cellbio\lib\site-packages\tyssue\solvers\quasistatic.py:139, in QSSolver.check_grad(self, eptm, geom, model)
#     135 def check_grad(self, eptm, geom, model):
#     136     pos0 = eptm.vert_df.loc[
#     137         eptm.vert_df.is_active.astype(bool), eptm.coords
#     138     ].values.ravel()
# --> 139     grad_err = optimize.check_grad(
#     140         self._opt_energy, self._opt_grad, pos0.flatten(), eptm, geom, model
#     141     )
#     142     return grad_err
#
# File c:\Users\Thomas\anaconda3\envs\cellbio\lib\site-packages\scipy\optimize\_optimize.py:1103, in check_grad(func, grad, x0, epsilon, direction, seed, *args)
#    1098 else:
#    1099     raise ValueError(f"{direction} is not a valid string for "
#    1100                      "``direction`` argument")
#    1102 return np.sqrt(np.sum(np.abs(
# -> 1103     (analytical_grad - approx_fprime(vars, _func, step, *_args))**2
#    1104 )))
#
# File c:\Users\Thomas\anaconda3\envs\cellbio\lib\site-packages\scipy\optimize\_optimize.py:1008, in approx_fprime(xk, f, epsilon, *args)
#    1005 xk = np.asarray(xk, float)
#    1006 f0 = f(xk, *args)
# -> 1008 return approx_derivative(f, xk, method='2-point', abs_step=epsilon,
#    1009                          args=args, f0=f0)
#
# File c:\Users\Thomas\anaconda3\envs\cellbio\lib\site-packages\scipy\optimize\_numdiff.py:519, in approx_derivative(fun, x0, method, rel_step, abs_step, f0, bounds, sparsity, as_linear_operator, args, kwargs)
#     516     use_one_sided = False
#     518 if sparsity is None:
# --> 519     return _dense_difference(fun_wrapped, x0, f0, h,
#     520                              use_one_sided, method)
#     521 else:
#     522     if not issparse(sparsity) and len(sparsity) == 2:
#
# File c:\Users\Thomas\anaconda3\envs\cellbio\lib\site-packages\scipy\optimize\_numdiff.py:590, in _dense_difference(fun, x0, f0, h, use_one_sided, method)
#     588     x = x0 + h_vecs[i]
#     589     dx = x[i] - x0[i]  # Recompute dx as exactly representable number.
# --> 590     df = fun(x) - f0
#     591 elif method == '3-point' and use_one_sided[i]:
#     592     x1 = x0 + h_vecs[i]
#
# File c:\Users\Thomas\anaconda3\envs\cellbio\lib\site-packages\scipy\optimize\_numdiff.py:470, in approx_derivative.<locals>.fun_wrapped(x)
#     467 if xp.isdtype(x.dtype, "real floating"):
#     468     x = xp.astype(x, x0.dtype)
# --> 470 f = np.atleast_1d(fun(x, *args, **kwargs))
#     471 if f.ndim > 1:
#     472     raise RuntimeError("`fun` return value has "
#     473                        "more than 1 dimension.")
#
# File c:\Users\Thomas\anaconda3\envs\cellbio\lib\site-packages\tyssue\solvers\quasistatic.py:118, in QSSolver._opt_energy(self, pos, eptm, geom, model)
#     116     eptm.topo_changed = False
#     117     raise TopologyChangeError("Topology changed before energy evaluation")
# --> 118 self.set_pos(eptm, geom, pos)
#     119 return model.compute_energy(eptm)
#
# File c:\Users\Thomas\anaconda3\envs\cellbio\lib\site-packages\tyssue\solvers\base.py:21, in set_pos(eptm, geom, pos)
#      17     raise TopologyChangeError
#      18 eptm.vert_df.loc[eptm.vert_df.is_active.astype(bool), eptm.coords] = pos.reshape(
#      19     (-1, eptm.dim)
#      20 )
# ---> 21 geom.update_all(eptm)
#
# File c:\Users\Thomas\anaconda3\envs\cellbio\lib\site-packages\tyssue\geometry\sheet_geometry.py:24, in SheetGeometry.update_all(cls, sheet)
#      11 @classmethod
#      12 def update_all(cls, sheet):
#      13     """
#      14     Updates the sheet geometry by updating:
#      15     * the edge vector coordinates
#    (...)
#      22
#      23     """
# ---> 24     cls.update_dcoords(sheet)
#      25     cls.update_ucoords(sheet)
#      26     cls.update_length(sheet)
#
# File c:\Users\Thomas\anaconda3\envs\cellbio\lib\site-packages\tyssue\geometry\base_geometry.py:35, in BaseGeometry.update_dcoords(sheet)
#      33 srce_pos = sheet.upcast_srce(data)
#      34 trgt_pos = sheet.upcast_trgt(data)
# ---> 35 sheet.edge_df[["s" + c for c in sheet.coords]] = srce_pos
#      36 sheet.edge_df[["t" + c for c in sheet.coords]] = trgt_pos
#      37 sheet.edge_df[sheet.dcoords] = trgt_pos - srce_pos
#
# File c:\Users\Thomas\anaconda3\envs\cellbio\lib\site-packages\pandas\core\frame.py:3968, in DataFrame.__setitem__(self, key, value)
#    3966     self._setitem_frame(key, value)
#    3967 elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 3968     self._setitem_array(key, value)
#    3969 elif isinstance(value, DataFrame):
#    3970     self._set_item_frame_value(key, value)
#
# File c:\Users\Thomas\anaconda3\envs\cellbio\lib\site-packages\pandas\core\frame.py:4012, in DataFrame._setitem_array(self, key, value)
#    4010     check_key_length(self.columns, key, value)
#    4011     for k1, k2 in zip(key, value.columns):
# -> 4012         self[k1] = value[k2]
#    4014 elif not is_list_like(value):
#    4015     for col in key:
#
# File c:\Users\Thomas\anaconda3\envs\cellbio\lib\site-packages\pandas\core\frame.py:3980, in DataFrame.__setitem__(self, key, value)
#    3977     self._setitem_array([key], value)
#    3978 else:
#    3979     # set column
# -> 3980     self._set_item(key, value)
#
# File c:\Users\Thomas\anaconda3\envs\cellbio\lib\site-packages\pandas\core\frame.py:4187, in DataFrame._set_item(self, key, value)
#    4184         if isinstance(existing_piece, DataFrame):
#    4185             value = np.tile(value, (len(existing_piece.columns), 1)).T
# -> 4187 self._set_item_mgr(key, value)
#
# File c:\Users\Thomas\anaconda3\envs\cellbio\lib\site-packages\pandas\core\frame.py:4146, in DataFrame._set_item_mgr(self, key, value)
#    4144     self._mgr.insert(len(self._info_axis), key, value)
#    4145 else:
# -> 4146     self._iset_item_mgr(loc, value)
#    4148 # check if we are modifying a copy
#    4149 # try to set first as we want an invalid
#    4150 # value exception to occur first
#    4151 if len(self):
#
# File c:\Users\Thomas\anaconda3\envs\cellbio\lib\site-packages\pandas\core\frame.py:4136, in DataFrame._iset_item_mgr(self, loc, value, inplace)
#    4132 def _iset_item_mgr(
#    4133     self, loc: int | slice | np.ndarray, value, inplace: bool = False
#    4134 ) -> None:
#    4135     # when called from _set_item_mgr loc can be anything returned from get_loc
# -> 4136     self._mgr.iset(loc, value, inplace=inplace)
#    4137     self._clear_item_cache()
#
# File c:\Users\Thomas\anaconda3\envs\cellbio\lib\site-packages\pandas\core\internals\managers.py:1268, in BlockManager.iset(self, loc, value, inplace)
#    1266     removed_blknos.append(blkno_l)
#    1267 else:
# -> 1268     nb = blk.delete(blk_locs)
#    1269     blocks_tup = (
#    1270         self.blocks[:blkno_l] + (nb,) + self.blocks[blkno_l + 1 :]
#    1271     )
#    1272     self.blocks = blocks_tup
#
# File c:\Users\Thomas\anaconda3\envs\cellbio\lib\site-packages\pandas\core\internals\blocks.py:1921, in NumpyBlock.delete(self, loc)
#    1920 def delete(self, loc) -> Block:
# -> 1921     values = np.delete(self.values, loc, 0)
#    1922     mgr_locs = self._mgr_locs.delete(loc)
#    1923     return type(self)(values, placement=mgr_locs, ndim=self.ndim)
#
# File c:\Users\Thomas\anaconda3\envs\cellbio\lib\site-packages\numpy\lib\function_base.py:5342, in delete(arr, obj, axis)
#    5340     slobj2 = [slice(None)]*ndim
#    5341     slobj2[axis] = slice(obj+1, None)
# -> 5342     new[tuple(slobj)] = arr[tuple(slobj2)]
#    5343 else:
#    5344     if obj.dtype == bool:
#
# KeyboardInterrupt:

# %%
app_grad = solver.approx_grad(sheet, geom, model)

# %%
app_grad = pd.DataFrame(app_grad.reshape((-1, 3)), columns=['gx', 'gy', 'gz'])

# %%
app_grad.head()
# Out:
#          gx        gy   gz
# 0 -0.000146  0.000178  0.0
# 1 -0.000592  0.000862  0.0
# 2  0.000279 -0.001306  0.0
# 3 -0.000259  0.000547  0.0
# 4 -0.000371 -0.000068  0.0

# %% [markdown]
# # Euler solver

# %% [markdown]
# This notebooks demonstrates usage of the time dependent solver `EulerSolver` in the simplest case where we solve
# $$\eta_i \frac{d\mathbf{r}_i}{dt}  = \mathbf{F}_i = - \mathbf{\nabla}_i E$$
#
# The model is used in the same way as the quasistatic solver.

# %% [markdown]
# ## Simple forward Euler solver
#
# $$\mathbf{r}_i(t+dt) = \mathbf{r}_i(t) + \frac{\mathbf{F}_i(t)}{\eta} dt$$

# %%
sheet = Sheet('3', *three_faces_sheet())
geom.update_all(sheet)
sheet.settings['threshold_length'] = 1e-3

sheet.update_specs(config.dynamics.quasistatic_plane_spec())
sheet.face_df["prefered_area"] = sheet.face_df["area"].mean()
history = History(sheet) #, extra_cols={"edge":["dx", "dy", "sx", "sy", "tx", "ty"]})

sheet.vert_df['viscosity'] = 1.0
sheet.edge_df.loc[[0, 17],  'line_tension'] *= 4
sheet.face_df.loc[1,  'prefered_area'] *= 1.2

fig, ax = plot_forces(sheet, geom, model, ['x', 'y'], 1)

# %% [markdown]
# Solver instanciation &mdash; contrary to the quasistatic solver, this solver needs the sheet, geometry and model at instanciation time:

# %%
solver = EulerSolver(
    sheet,
    geom,
    model,
    history=history,
    auto_reconnect=True)

# %% [markdown]
# The solver's `solve` method accepts a `on_topo_change` function as argument. This function is executed each time a topology change occurs. Here, we reste the line tension to its original value.

# %%
def on_topo_change(sheet):
    print('Topology changed!\n')
    print("reseting tension")
    sheet.edge_df["line_tension"] = sheet.specs["edge"]["line_tension"]

# %% [markdown]
# ### Solving from $t = 0$ to $t = 15$

# %%
res = solver.solve(tf=15, dt=0.05, on_topo_change=on_topo_change,
                   topo_change_args=(solver.eptm,))
# Out:
# Topology changed!
#
# reseting tension
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 res = solver.solve(tf=15, dt=0.05, on_topo_change=on_topo_change,
#       2                    topo_change_args=(solver.eptm,))
#
# File c:\Users\Thomas\anaconda3\envs\cellbio\lib\site-packages\tyssue\solvers\viscous.py:131, in EulerSolver.solve(self, tf, dt, on_topo_change, topo_change_args)
#     129     dot_r = np.clip(dot_r, *self.bounds)
#     130 pos = pos + dot_r * dt
# --> 131 self.set_pos(pos)
#     132 self.prev_t = t
#     133 if self.manager is not None:
#
# File c:\Users\Thomas\anaconda3\envs\cellbio\lib\site-packages\tyssue\solvers\viscous.py:106, in EulerSolver.set_pos(self, pos)
#     103 def set_pos(self, pos):
#     104     """Updates the eptm vertices position
#     105     """
# --> 106     return self._set_pos(self.eptm, self.geom, pos)
#
# File c:\Users\Thomas\anaconda3\envs\cellbio\lib\site-packages\tyssue\solvers\viscous.py:31, in set_pos(eptm, geom, pos)
#      29 log.debug("set pos")
#      30 eptm.vert_df.loc[eptm.active_verts, eptm.coords] = pos.reshape((-1, eptm.dim))
# ---> 31 geom.update_all(eptm)
#
# File c:\Users\Thomas\anaconda3\envs\cellbio\lib\site-packages\tyssue\geometry\sheet_geometry.py:24, in SheetGeometry.update_all(cls, sheet)
#      11 @classmethod
#      12 def update_all(cls, sheet):
#      13     """
#      14     Updates the sheet geometry by updating:
#      15     * the edge vector coordinates
#    (...)
#      22
#      23     """
# ---> 24     cls.update_dcoords(sheet)
#      25     cls.update_ucoords(sheet)
#      26     cls.update_length(sheet)
#
# File c:\Users\Thomas\anaconda3\envs\cellbio\lib\site-packages\tyssue\geometry\base_geometry.py:35, in BaseGeometry.update_dcoords(sheet)
#      33 srce_pos = sheet.upcast_srce(data)
#      34 trgt_pos = sheet.upcast_trgt(data)
# ---> 35 sheet.edge_df[["s" + c for c in sheet.coords]] = srce_pos
#      36 sheet.edge_df[["t" + c for c in sheet.coords]] = trgt_pos
#      37 sheet.edge_df[sheet.dcoords] = trgt_pos - srce_pos
#
# File c:\Users\Thomas\anaconda3\envs\cellbio\lib\site-packages\pandas\core\frame.py:3968, in DataFrame.__setitem__(self, key, value)
#    3966     self._setitem_frame(key, value)
#    3967 elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 3968     self._setitem_array(key, value)
#    3969 elif isinstance(value, DataFrame):
#    3970     self._set_item_frame_value(key, value)
#
# File c:\Users\Thomas\anaconda3\envs\cellbio\lib\site-packages\pandas\core\frame.py:4012, in DataFrame._setitem_array(self, key, value)
#    4010     check_key_length(self.columns, key, value)
#    4011     for k1, k2 in zip(key, value.columns):
# -> 4012         self[k1] = value[k2]
#    4014 elif not is_list_like(value):
#    4015     for col in key:
#
# File c:\Users\Thomas\anaconda3\envs\cellbio\lib\site-packages\pandas\core\frame.py:3980, in DataFrame.__setitem__(self, key, value)
#    3977     self._setitem_array([key], value)
#    3978 else:
#    3979     # set column
# -> 3980     self._set_item(key, value)
#
# File c:\Users\Thomas\anaconda3\envs\cellbio\lib\site-packages\pandas\core\frame.py:4187, in DataFrame._set_item(self, key, value)
#    4184         if isinstance(existing_piece, DataFrame):
#    4185             value = np.tile(value, (len(existing_piece.columns), 1)).T
# -> 4187 self._set_item_mgr(key, value)
#
# File c:\Users\Thomas\anaconda3\envs\cellbio\lib\site-packages\pandas\core\frame.py:4146, in DataFrame._set_item_mgr(self, key, value)
#    4144     self._mgr.insert(len(self._info_axis), key, value)
#    4145 else:
# -> 4146     self._iset_item_mgr(loc, value)
#    4148 # check if we are modifying a copy
#    4149 # try to set first as we want an invalid
#    4150 # value exception to occur first
#    4151 if len(self):
#
# File c:\Users\Thomas\anaconda3\envs\cellbio\lib\site-packages\pandas\core\frame.py:4136, in DataFrame._iset_item_mgr(self, loc, value, inplace)
#    4132 def _iset_item_mgr(
#    4133     self, loc: int | slice | np.ndarray, value, inplace: bool = False
#    4134 ) -> None:
#    4135     # when called from _set_item_mgr loc can be anything returned from get_loc
# -> 4136     self._mgr.iset(loc, value, inplace=inplace)
#    4137     self._clear_item_cache()
#
# File c:\Users\Thomas\anaconda3\envs\cellbio\lib\site-packages\pandas\core\internals\managers.py:1245, in BlockManager.iset(self, loc, value, inplace)
#    1243 # Accessing public blknos ensures the public versions are initialized
#    1244 blknos = self.blknos[loc]
# -> 1245 blklocs = self.blklocs[loc].copy()
#    1247 unfit_mgr_locs = []
#    1248 unfit_val_locs = []
#
# KeyboardInterrupt:

# %% [markdown]
# ## Showing the results

# %%
create_gif(solver.history, "sheet3.gif", num_frames=120)

# %%
Image("sheet3.gif")
